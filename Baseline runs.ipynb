# %%
from learning import learn_pool

env_config = {'environment_name' : 'Hanabi-Small', 'num_players' : 2, 
              'use_custom_rewards' : False, 'open_hands' : False}

model_config_base = {'scope' : 'agent_test', 'nenvs'  : 32,  'nsteps' : None,
           'fc_input_layers' : [128, ], 'lstm_layers' : [128], 'noisy_fc' : False, 'v_net' : 'copy',
           'gamma' : 0.99, 'ent_coef' : 0.0, 'vf_coef' : 1, 'cliprange' : 0.2,
           'max_grad_norm' : None, 'k' : 24,  
           'lr' : 1e-4, 'lr_half_period' : 50000, 'anneal_lr' : False,
           'normalize_advs': True, 'layer_norm' : False,
           }
rewards_config = {}
folder = './experiments/baselines/'
method = 'self play'
run_copies = 2

# %% [markdown]
# ### lstm and fc

# %%
k = 8
nsteps = 6
numepochs = 120000 // nsteps
folder = './experiments/baselines/architecture/'

#LSTM copy
mc = dict(model_config_base)
mc['k'] = k
mc['nsteps'] = nsteps
mc['lstm_layers'] = [128]
mc['v_net'] = 'copy'
runname = 'LSTM_copy_k:%d_steps:%d' %(k, nsteps)
learn_pool.run_experiment(runname, [mc], env_config, rewards_config, numepochs, 
                          folder = folder, method = method, nsteps = nsteps,)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1206 01:24:16.667963 139962930890560 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/learning/learn_pool.py:99: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W1206 01:24:16.668943 139962930890560 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/learning/learn_pool.py:100: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1206 01:24:16.964672 139962930890560 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:50: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1206 01:24:16.985080 139962930890560 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:60: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W1206 01:24:16.990747 139962930890560 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:65: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1206 01:24:16.999381 139962930890560 deprecation.py:323] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_util.py:351: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# GAME PARAMETERS:
#   observation length = 171
#   number of actions = 11
#   number of players = 2
# <class 'PPO.lstm_ppo.Model'>
# W1206 01:24:17.569127 139962930890560 deprecation.py:323] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_network.py:110: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# W1206 01:24:18.131184 139962930890560 deprecation.py:323] From /home/gr1/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1206 01:24:20.308498 139962930890560 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:118: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W1206 01:24:20.564490 139962930890560 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:125: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W1206 01:24:20.622803 139962930890560 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:126: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# W1206 01:24:22.631956 139962930890560 deprecation.py:323] From /home/gr1/.local/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# Successfully loaded model "agent_test":
#   "agent_test" was trained for 77100 epochs, using 38550720 timesteps
#   "agent_test" has following parameters: k = 8, cliprange = 0.2, lr = 0.000100
#   "agent_test" has following rewards_config: {}
# /home/gr1/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/gr1/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Savinig models after 100 epochs of training
# Average env speed is 2002 ts/second
#
# Savinig models after 200 epochs of training
# Average env speed is 2099 ts/second
# ---------------200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    4.946875
# ---------------------------------
#
# Savinig models after 300 epochs of training
# Average env speed is 2130 ts/second
#
# Savinig models after 400 epochs of training
# Average env speed is 2045 ts/second
# ---------------400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    5.096875
# ---------------------------------
#
# Savinig models after 500 epochs of training
# Average env speed is 2358 ts/second
#
# Savinig models after 600 epochs of training
# Average env speed is 2213 ts/second
# ---------------600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      5.1125
# ---------------------------------
#
# Savinig models after 700 epochs of training
# Average env speed is 2384 ts/second
#
# Savinig models after 800 epochs of training
# Average env speed is 2259 ts/second
# ---------------800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    5.028125
# ---------------------------------
#
# Savinig models after 900 epochs of training
# Average env speed is 2478 ts/second
#
# Savinig models after 1000 epochs of training
# Average env speed is 2273 ts/second
# ---------------1000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      5.0125
# ----------------------------------
#
# Savinig models after 1100 epochs of training
# Average env speed is 2455 ts/second
#
# Savinig models after 1200 epochs of training
# Average env speed is 2252 ts/second
# ---------------1200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    4.990625
# ----------------------------------
#
# Savinig models after 1300 epochs of training
# Average env speed is 2409 ts/second
#
# Savinig models after 1400 epochs of training
# Average env speed is 2188 ts/second
# ---------------1400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    5.071875
# ----------------------------------
#
# Savinig models after 1500 epochs of training
# Average env speed is 2392 ts/second
#
# Savinig models after 1600 epochs of training
# Average env speed is 2303 ts/second
# ---------------1600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      5.1875
# ----------------------------------
#
# Savinig models after 1700 epochs of training
# Average env speed is 2450 ts/second
#
# Savinig models after 1800 epochs of training
# Average env speed is 2289 ts/second
# ---------------1800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    5.159375
# ----------------------------------

# %%
k = 8
nsteps = 6
numepochs = 480000 // nsteps
folder = './experiments/baselines/architecture/'

#LSTM noisy
mc = dict(model_config_base)
mc['k'] = k
mc['nsteps'] = nsteps
mc['lstm_layers'] = [128]
mc['v_net'] = 'copy'
mc['noisy_fc'] = True
runname = 'LSTM_copy_k:%d_steps:%d' %(k, nsteps)
learn_pool.run_experiment(runname, [mc], env_config, rewards_config, numepochs, 
                          folder = folder, method = method, nsteps = nsteps,)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1205 04:45:14.651728 140429179070272 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/learning/learn_pool.py:99: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# W1205 04:45:14.653117 140429179070272 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/learning/learn_pool.py:100: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W1205 04:45:15.021230 140429179070272 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:50: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1205 04:45:15.040529 140429179070272 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:60: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W1205 04:45:15.047807 140429179070272 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:65: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W1205 04:45:15.058358 140429179070272 deprecation.py:323] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_util.py:351: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# GAME PARAMETERS:
#   observation length = 171
#   number of actions = 11
#   number of players = 2
# <class 'PPO.lstm_ppo.Model'>
# W1205 04:45:15.467658 140429179070272 deprecation.py:323] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_network.py:110: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# W1205 04:45:15.747858 140429179070272 deprecation.py:323] From /home/gr1/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W1205 04:45:18.015356 140429179070272 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:118: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# W1205 04:45:18.211631 140429179070272 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:125: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# W1205 04:45:18.262719 140429179070272 deprecation_wrapper.py:119] From /home/gr1/Documents/HLE github/hanabi/PPO/lstm_ppo.py:126: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Could not load model "agent_test" at ./experiments/baselines/architecture/Hanabi-Small-2/LSTM_shared_k:8_steps:6/agent_test/model/
#
# Savinig models after 100 epochs of training
# Average env speed is 2261 ts/second
#
# Savinig models after 200 epochs of training
# Average env speed is 2444 ts/second
# ---------------200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      0.9875
# ---------------------------------
#
# Savinig models after 300 epochs of training
# Average env speed is 2604 ts/second
#
# Savinig models after 400 epochs of training
# Average env speed is 2522 ts/second
# ---------------400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.04375
# ---------------------------------
#
# Savinig models after 500 epochs of training
# Average env speed is 2727 ts/second
#
# Savinig models after 600 epochs of training
# Average env speed is 2537 ts/second
# ---------------600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.0875
# ---------------------------------
#
# Savinig models after 700 epochs of training
# Average env speed is 2697 ts/second
#
# Savinig models after 800 epochs of training
# Average env speed is 2536 ts/second
# ---------------800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.128125
# ---------------------------------
#
# Savinig models after 900 epochs of training
# Average env speed is 2734 ts/second
#
# Savinig models after 1000 epochs of training
# Average env speed is 2529 ts/second
# ---------------1000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.05625
# ----------------------------------
#
# Savinig models after 1100 epochs of training
# Average env speed is 2659 ts/second
#
# Savinig models after 1200 epochs of training
# Average env speed is 2259 ts/second
# ---------------1200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.05625
# ----------------------------------
#
# Savinig models after 1300 epochs of training
# Average env speed is 2522 ts/second
#
# Savinig models after 1400 epochs of training
# Average env speed is 2205 ts/second
# ---------------1400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.121875
# ----------------------------------
#
# Savinig models after 1500 epochs of training
# Average env speed is 2619 ts/second
#
# Savinig models after 1600 epochs of training
# Average env speed is 2522 ts/second
# ---------------1600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.365625
# ----------------------------------
#
# Savinig models after 1700 epochs of training
# Average env speed is 2688 ts/second
#
# Savinig models after 1800 epochs of training
# Average env speed is 2500 ts/second
# ---------------1800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.30625
# ----------------------------------
#
# Savinig models after 1900 epochs of training
# Average env speed is 2707 ts/second
#
# Savinig models after 2000 epochs of training
# Average env speed is 2496 ts/second
# ---------------2000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.453125
# ----------------------------------
#
# Savinig models after 2100 epochs of training
# Average env speed is 2689 ts/second
#
# Savinig models after 2200 epochs of training
# Average env speed is 2496 ts/second
# ---------------2200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.55625
# ----------------------------------
#
# Savinig models after 2300 epochs of training
# Average env speed is 2676 ts/second
#
# Savinig models after 2400 epochs of training
# Average env speed is 2496 ts/second
# ---------------2400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.546875
# ----------------------------------
#
# Savinig models after 2500 epochs of training
# Average env speed is 2683 ts/second
#
# Savinig models after 2600 epochs of training
# Average env speed is 2552 ts/second
# ---------------2600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test         1.6
# ----------------------------------
#
# Savinig models after 2700 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 2800 epochs of training
# Average env speed is 2566 ts/second
# ---------------2800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.640625
# ----------------------------------
#
# Savinig models after 2900 epochs of training
# Average env speed is 2761 ts/second
#
# Savinig models after 3000 epochs of training
# Average env speed is 2559 ts/second
# ---------------3000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.565625
# ----------------------------------
#
# Savinig models after 3100 epochs of training
# Average env speed is 2750 ts/second
#
# Savinig models after 3200 epochs of training
# Average env speed is 2552 ts/second
# ---------------3200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.65625
# ----------------------------------
#
# Savinig models after 3300 epochs of training
# Average env speed is 2763 ts/second
#
# Savinig models after 3400 epochs of training
# Average env speed is 2542 ts/second
# ---------------3400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.63125
# ----------------------------------
#
# Savinig models after 3500 epochs of training
# Average env speed is 2751 ts/second
#
# Savinig models after 3600 epochs of training
# Average env speed is 2564 ts/second
# ---------------3600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test         1.6
# ----------------------------------
#
# Savinig models after 3700 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 3800 epochs of training
# Average env speed is 2555 ts/second
# ---------------3800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.665625
# ----------------------------------
#
# Savinig models after 3900 epochs of training
# Average env speed is 2767 ts/second
#
# Savinig models after 4000 epochs of training
# Average env speed is 2552 ts/second
# ---------------4000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.675
# ----------------------------------
#
# Savinig models after 4100 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 4200 epochs of training
# Average env speed is 2538 ts/second
# ---------------4200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.53125
# ----------------------------------
#
# Savinig models after 4300 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 4400 epochs of training
# Average env speed is 2562 ts/second
# ---------------4400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.728125
# ----------------------------------
#
# Savinig models after 4500 epochs of training
# Average env speed is 2766 ts/second
#
# Savinig models after 4600 epochs of training
# Average env speed is 2552 ts/second
# ---------------4600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.3875
# ----------------------------------
#
# Savinig models after 4700 epochs of training
# Average env speed is 2774 ts/second
#
# Savinig models after 4800 epochs of training
# Average env speed is 2561 ts/second
# ---------------4800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.63125
# ----------------------------------
#
# Savinig models after 4900 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 5000 epochs of training
# Average env speed is 2560 ts/second
# ---------------5000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.740625
# ----------------------------------
# Savinig models after 5100 epochs of training
# Average env speed is 2755 ts/second
#
# Savinig models after 5200 epochs of training
# Average env speed is 2568 ts/second
# ---------------5200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.678125
# ----------------------------------
#
# Savinig models after 5300 epochs of training
# Average env speed is 2768 ts/second
#
# Savinig models after 5400 epochs of training
# Average env speed is 2555 ts/second
# ---------------5400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.625
# ----------------------------------
#
# Savinig models after 5500 epochs of training
# Average env speed is 2767 ts/second
#
# Savinig models after 5600 epochs of training
# Average env speed is 2547 ts/second
# ---------------5600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.565625
# ----------------------------------
#
# Savinig models after 5700 epochs of training
# Average env speed is 2760 ts/second
#
# Savinig models after 5800 epochs of training
# Average env speed is 2569 ts/second
# ---------------5800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.628125
# ----------------------------------
#
# Savinig models after 5900 epochs of training
# Average env speed is 2763 ts/second
#
# Savinig models after 6000 epochs of training
# Average env speed is 2559 ts/second
# ---------------6000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.671875
# ----------------------------------
#
# Savinig models after 6100 epochs of training
# Average env speed is 2759 ts/second
#
# Savinig models after 6200 epochs of training
# Average env speed is 2560 ts/second
# ---------------6200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.509375
# ----------------------------------
#
# Savinig models after 6300 epochs of training
# Average env speed is 2770 ts/second
#
# Savinig models after 6400 epochs of training
# Average env speed is 2557 ts/second
# ---------------6400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.703125
# ----------------------------------
#
# Savinig models after 6500 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 6600 epochs of training
# Average env speed is 2562 ts/second
# ---------------6600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.465625
# ----------------------------------
#
# Savinig models after 6700 epochs of training
# Average env speed is 2752 ts/second
#
# Savinig models after 6800 epochs of training
# Average env speed is 2580 ts/second
# ---------------6800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.58125
# ----------------------------------
#
# Savinig models after 6900 epochs of training
# Average env speed is 2755 ts/second
#
# Savinig models after 7000 epochs of training
# Average env speed is 2546 ts/second
# ---------------7000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.7625
# ----------------------------------
#
# Savinig models after 7100 epochs of training
# Average env speed is 2771 ts/second
#
# Savinig models after 7200 epochs of training
# Average env speed is 2561 ts/second
# ---------------7200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.68125
# ----------------------------------
#
# Savinig models after 7300 epochs of training
# Average env speed is 2756 ts/second
#
# Savinig models after 7400 epochs of training
# Average env speed is 2577 ts/second
# ---------------7400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.921875
# ----------------------------------
#
# Savinig models after 7500 epochs of training
# Average env speed is 2755 ts/second
#
# Savinig models after 7600 epochs of training
# Average env speed is 2575 ts/second
# ---------------7600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.825
# ----------------------------------
#
# Savinig models after 7700 epochs of training
# Average env speed is 2745 ts/second
#
# Savinig models after 7800 epochs of training
# Average env speed is 2553 ts/second
# ---------------7800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# ----------------------------------
# /home/gr1/.local/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/gr1/.local/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Savinig models after 7900 epochs of training
# Average env speed is 2779 ts/second
#
# Savinig models after 8000 epochs of training
# Average env speed is 2567 ts/second
# ---------------8000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9375
# ----------------------------------
#
# Savinig models after 8100 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 8200 epochs of training
# Average env speed is 2573 ts/second
# ---------------8200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# ----------------------------------
#
# Savinig models after 8300 epochs of training
# Average env speed is 2760 ts/second
#
# Savinig models after 8400 epochs of training
# Average env speed is 2564 ts/second
# ---------------8400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.984375
# ----------------------------------
#
# Savinig models after 8500 epochs of training
# Average env speed is 2749 ts/second
#
# Savinig models after 8600 epochs of training
# Average env speed is 2566 ts/second
# ---------------8600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9375
# ----------------------------------
#
# Savinig models after 8700 epochs of training
# Average env speed is 2770 ts/second
#
# Savinig models after 8800 epochs of training
# Average env speed is 2555 ts/second
# ---------------8800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.940625
# ----------------------------------
#
# Savinig models after 8900 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 9000 epochs of training
# Average env speed is 2574 ts/second
# ---------------9000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# ----------------------------------
#
# Savinig models after 9100 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 9200 epochs of training
# Average env speed is 2560 ts/second
# ---------------9200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# ----------------------------------
#
# Savinig models after 9300 epochs of training
# Average env speed is 2774 ts/second
#
# Savinig models after 9400 epochs of training
# Average env speed is 2550 ts/second
# ---------------9400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.95625
# ----------------------------------
#
# Savinig models after 9500 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 9600 epochs of training
# Average env speed is 2562 ts/second
# ---------------9600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.6625
# ----------------------------------
#
# Savinig models after 9700 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 9800 epochs of training
# Average env speed is 2578 ts/second
# ---------------9800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.975
# ----------------------------------
#
# Savinig models after 9900 epochs of training
# Average env speed is 2747 ts/second
#
# Savinig models after 10000 epochs of training
# Average env speed is 2534 ts/second
# ---------------10000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 10100 epochs of training
# Average env speed is 2764 ts/second
#
# Savinig models after 10200 epochs of training
# Average env speed is 2542 ts/second
# ---------------10200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9125
# -----------------------------------
#
# Savinig models after 10300 epochs of training
# Average env speed is 2763 ts/second
#
# Savinig models after 10400 epochs of training
# Average env speed is 2548 ts/second
# ---------------10400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 10500 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 10600 epochs of training
# Average env speed is 2573 ts/second
# ---------------10600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.975
# -----------------------------------
#
# Savinig models after 10700 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 10800 epochs of training
# Average env speed is 2554 ts/second
# ---------------10800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.990625
# -----------------------------------
#
# Savinig models after 10900 epochs of training
# Average env speed is 2767 ts/second
#
# Savinig models after 11000 epochs of training
# Average env speed is 2552 ts/second
# ---------------11000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 11100 epochs of training
# Average env speed is 2752 ts/second
#
# Savinig models after 11200 epochs of training
# Average env speed is 2564 ts/second
# ---------------11200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.96875
# -----------------------------------
#
# Savinig models after 11300 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 11400 epochs of training
# Average env speed is 2565 ts/second
# ---------------11400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9375
# -----------------------------------
#
# Savinig models after 11500 epochs of training
# Average env speed is 2759 ts/second
#
# Savinig models after 11600 epochs of training
# Average env speed is 2553 ts/second
# ---------------11600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test         2.0
# -----------------------------------
#
# Savinig models after 11700 epochs of training
# Average env speed is 2773 ts/second
#
# Savinig models after 11800 epochs of training
# Average env speed is 2558 ts/second
# ---------------11800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.915625
# -----------------------------------
#
# Savinig models after 11900 epochs of training
# Average env speed is 2759 ts/second
#
# Savinig models after 12000 epochs of training
# Average env speed is 2562 ts/second
# ---------------12000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.875
# -----------------------------------
#
# Savinig models after 12100 epochs of training
# Average env speed is 2749 ts/second
#
# Savinig models after 12200 epochs of training
# Average env speed is 2568 ts/second
# ---------------12200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.934375
# -----------------------------------
#
# Savinig models after 12300 epochs of training
# Average env speed is 2761 ts/second
#
# Savinig models after 12400 epochs of training
# Average env speed is 2552 ts/second
# ---------------12400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9625
# -----------------------------------
#
# Savinig models after 12500 epochs of training
# Average env speed is 2771 ts/second
#
# Savinig models after 12600 epochs of training
# Average env speed is 2558 ts/second
# ---------------12600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test         2.0
# -----------------------------------
#
# Savinig models after 12700 epochs of training
# Average env speed is 2758 ts/second
#
# Savinig models after 12800 epochs of training
# Average env speed is 2574 ts/second
# ---------------12800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.89375
# -----------------------------------
# Savinig models after 12900 epochs of training
# Average env speed is 2756 ts/second
#
# Savinig models after 13000 epochs of training
# Average env speed is 2568 ts/second
# ---------------13000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 13100 epochs of training
# Average env speed is 2749 ts/second
#
# Savinig models after 13200 epochs of training
# Average env speed is 2553 ts/second
# ---------------13200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.975
# -----------------------------------
#
# Savinig models after 13300 epochs of training
# Average env speed is 2776 ts/second
#
# Savinig models after 13400 epochs of training
# Average env speed is 2536 ts/second
# ---------------13400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test         2.0
# -----------------------------------
#
# Savinig models after 13500 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 13600 epochs of training
# Average env speed is 2567 ts/second
# ---------------13600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 13700 epochs of training
# Average env speed is 2763 ts/second
#
# Savinig models after 13800 epochs of training
# Average env speed is 2562 ts/second
# ---------------13800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.94375
# -----------------------------------
#
# Savinig models after 13900 epochs of training
# Average env speed is 2747 ts/second
#
# Savinig models after 14000 epochs of training
# Average env speed is 2553 ts/second
# ---------------14000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9125
# -----------------------------------
#
# Savinig models after 14100 epochs of training
# Average env speed is 2774 ts/second
#
# Savinig models after 14200 epochs of training
# Average env speed is 2550 ts/second
# ---------------14200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 14300 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 14400 epochs of training
# Average env speed is 2582 ts/second
# ---------------14400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.975
# -----------------------------------
#
# Savinig models after 14500 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 14600 epochs of training
# Average env speed is 2555 ts/second
# ---------------14600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.925
# -----------------------------------
#
# Savinig models after 14700 epochs of training
# Average env speed is 2776 ts/second
#
# Savinig models after 14800 epochs of training
# Average env speed is 2534 ts/second
# ---------------14800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.971875
# -----------------------------------
#
# Savinig models after 14900 epochs of training
# Average env speed is 2775 ts/second
#
# Savinig models after 15000 epochs of training
# Average env speed is 2557 ts/second
# ---------------15000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 15100 epochs of training
# Average env speed is 2756 ts/second
#
# Savinig models after 15200 epochs of training
# Average env speed is 2577 ts/second
# ---------------15200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9125
# -----------------------------------
#
# Savinig models after 15300 epochs of training
# Average env speed is 2743 ts/second
#
# Savinig models after 15400 epochs of training
# Average env speed is 2544 ts/second
# ---------------15400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9625
# -----------------------------------
#
# Savinig models after 15500 epochs of training
# Average env speed is 2768 ts/second
#
# Savinig models after 15600 epochs of training
# Average env speed is 2552 ts/second
# ---------------15600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.984375
# -----------------------------------
#
# Savinig models after 15700 epochs of training
# Average env speed is 2782 ts/second
#
# Savinig models after 15800 epochs of training
# Average env speed is 2538 ts/second
# ---------------15800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 15900 epochs of training
# Average env speed is 2759 ts/second
#
# Savinig models after 16000 epochs of training
# Average env speed is 2576 ts/second
# ---------------16000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.990625
# -----------------------------------
#
# Savinig models after 16100 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 16200 epochs of training
# Average env speed is 2542 ts/second
# ---------------16200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 16300 epochs of training
# Average env speed is 2777 ts/second
#
# Savinig models after 16400 epochs of training
# Average env speed is 2554 ts/second
# ---------------16400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 16500 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 16600 epochs of training
# Average env speed is 2573 ts/second
# ---------------16600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 16700 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 16800 epochs of training
# Average env speed is 2573 ts/second
# ---------------16800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9625
# -----------------------------------
#
# Savinig models after 16900 epochs of training
# Average env speed is 2761 ts/second
#
# Savinig models after 17000 epochs of training
# Average env speed is 2558 ts/second
# ---------------17000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test        1.95
# -----------------------------------
#
# Savinig models after 17100 epochs of training
# Average env speed is 2772 ts/second
#
# Savinig models after 17200 epochs of training
# Average env speed is 2518 ts/second
# ---------------17200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.96875
# -----------------------------------
#
# Savinig models after 17300 epochs of training
# Average env speed is 2748 ts/second
#
# Savinig models after 17400 epochs of training
# Average env speed is 2572 ts/second
# ---------------17400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 17500 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 17600 epochs of training
# Average env speed is 2565 ts/second
# ---------------17600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.896875
# -----------------------------------
#
# Savinig models after 17700 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 17800 epochs of training
# Average env speed is 2547 ts/second
# ---------------17800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.965625
# -----------------------------------
# Savinig models after 17900 epochs of training
# Average env speed is 2774 ts/second
#
# Savinig models after 18000 epochs of training
# Average env speed is 2549 ts/second
# ---------------18000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.996875
# -----------------------------------
#
# Savinig models after 18100 epochs of training
# Average env speed is 2765 ts/second
#
# Savinig models after 18200 epochs of training
# Average env speed is 2566 ts/second
# ---------------18200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 18300 epochs of training
# Average env speed is 2752 ts/second
#
# Savinig models after 18400 epochs of training
# Average env speed is 2573 ts/second
# ---------------18400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.95625
# -----------------------------------
#
# Savinig models after 18500 epochs of training
# Average env speed is 2747 ts/second
#
# Savinig models after 18600 epochs of training
# Average env speed is 2551 ts/second
# ---------------18600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 18700 epochs of training
# Average env speed is 2774 ts/second
#
# Savinig models after 18800 epochs of training
# Average env speed is 2558 ts/second
# ---------------18800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.978125
# -----------------------------------
#
# Savinig models after 18900 epochs of training
# Average env speed is 2759 ts/second
#
# Savinig models after 19000 epochs of training
# Average env speed is 2577 ts/second
# ---------------19000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 19100 epochs of training
# Average env speed is 2756 ts/second
#
# Savinig models after 19200 epochs of training
# Average env speed is 2553 ts/second
# ---------------19200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.996875
# -----------------------------------
#
# Savinig models after 19300 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 19400 epochs of training
# Average env speed is 2550 ts/second
# ---------------19400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 19500 epochs of training
# Average env speed is 2769 ts/second
#
# Savinig models after 19600 epochs of training
# Average env speed is 2555 ts/second
# ---------------19600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 19700 epochs of training
# Average env speed is 2746 ts/second
#
# Savinig models after 19800 epochs of training
# Average env speed is 2566 ts/second
# ---------------19800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 19900 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 20000 epochs of training
# Average env speed is 2542 ts/second
# ---------------20000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.971875
# -----------------------------------
#
# Savinig models after 20100 epochs of training
# Average env speed is 2774 ts/second
#
# Savinig models after 20200 epochs of training
# Average env speed is 2555 ts/second
# ---------------20200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test         2.0
# -----------------------------------
#
# Savinig models after 20300 epochs of training
# Average env speed is 2779 ts/second
#
# Savinig models after 20400 epochs of training
# Average env speed is 2540 ts/second
# ---------------20400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.978125
# -----------------------------------
#
# Savinig models after 20500 epochs of training
# Average env speed is 2749 ts/second
#
# Savinig models after 20600 epochs of training
# Average env speed is 2565 ts/second
# ---------------20600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 20700 epochs of training
# Average env speed is 2755 ts/second
#
# Savinig models after 20800 epochs of training
# Average env speed is 2554 ts/second
# ---------------20800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.96875
# -----------------------------------
#
# Savinig models after 20900 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 21000 epochs of training
# Average env speed is 2543 ts/second
# ---------------21000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 21100 epochs of training
# Average env speed is 2741 ts/second
#
# Savinig models after 21200 epochs of training
# Average env speed is 2566 ts/second
# ---------------21200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 21300 epochs of training
# Average env speed is 2748 ts/second
#
# Savinig models after 21400 epochs of training
# Average env speed is 2576 ts/second
# ---------------21400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 21500 epochs of training
# Average env speed is 2751 ts/second
#
# Savinig models after 21600 epochs of training
# Average env speed is 2545 ts/second
# ---------------21600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.975
# -----------------------------------
#
# Savinig models after 21700 epochs of training
# Average env speed is 2770 ts/second
#
# Savinig models after 21800 epochs of training
# Average env speed is 2557 ts/second
# ---------------21800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.965625
# -----------------------------------
#
# Savinig models after 21900 epochs of training
# Average env speed is 2760 ts/second
#
# Savinig models after 22000 epochs of training
# Average env speed is 2561 ts/second
# ---------------22000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.965625
# -----------------------------------
#
# Savinig models after 22100 epochs of training
# Average env speed is 2765 ts/second
#
# Savinig models after 22200 epochs of training
# Average env speed is 2565 ts/second
# ---------------22200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.90625
# -----------------------------------
#
# Savinig models after 22300 epochs of training
# Average env speed is 2747 ts/second
#
# Savinig models after 22400 epochs of training
# Average env speed is 2551 ts/second
# ---------------22400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 22500 epochs of training
# Average env speed is 2768 ts/second
#
# Savinig models after 22600 epochs of training
# Average env speed is 2558 ts/second
# ---------------22600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test        1.95
# -----------------------------------
#
# Savinig models after 22700 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 22800 epochs of training
# Average env speed is 2566 ts/second
# ---------------22800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.96875
# -----------------------------------
# Savinig models after 22900 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 23000 epochs of training
# Average env speed is 2576 ts/second
# ---------------23000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.978125
# -----------------------------------
#
# Savinig models after 23100 epochs of training
# Average env speed is 2741 ts/second
#
# Savinig models after 23200 epochs of training
# Average env speed is 2553 ts/second
# ---------------23200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 23300 epochs of training
# Average env speed is 2776 ts/second
#
# Savinig models after 23400 epochs of training
# Average env speed is 2549 ts/second
# ---------------23400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 23500 epochs of training
# Average env speed is 2761 ts/second
#
# Savinig models after 23600 epochs of training
# Average env speed is 2557 ts/second
# ---------------23600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.990625
# -----------------------------------
#
# Savinig models after 23700 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 23800 epochs of training
# Average env speed is 2573 ts/second
# ---------------23800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 23900 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 24000 epochs of training
# Average env speed is 2542 ts/second
# ---------------24000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test        1.95
# -----------------------------------
#
# Savinig models after 24100 epochs of training
# Average env speed is 2770 ts/second
#
# Savinig models after 24200 epochs of training
# Average env speed is 2555 ts/second
# ---------------24200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 24300 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 24400 epochs of training
# Average env speed is 2572 ts/second
# ---------------24400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 24500 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 24600 epochs of training
# Average env speed is 2538 ts/second
# ---------------24600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.890625
# -----------------------------------
#
# Savinig models after 24700 epochs of training
# Average env speed is 2765 ts/second
#
# Savinig models after 24800 epochs of training
# Average env speed is 2555 ts/second
# ---------------24800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.96875
# -----------------------------------
#
# Savinig models after 24900 epochs of training
# Average env speed is 2767 ts/second
#
# Savinig models after 25000 epochs of training
# Average env speed is 2541 ts/second
# ---------------25000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.946875
# -----------------------------------
#
# Savinig models after 25100 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 25200 epochs of training
# Average env speed is 2570 ts/second
# ---------------25200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 25300 epochs of training
# Average env speed is 2750 ts/second
#
# Savinig models after 25400 epochs of training
# Average env speed is 2545 ts/second
# ---------------25400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9625
# -----------------------------------
#
# Savinig models after 25500 epochs of training
# Average env speed is 2771 ts/second
#
# Savinig models after 25600 epochs of training
# Average env speed is 2548 ts/second
# ---------------25600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.93125
# -----------------------------------
#
# Savinig models after 25700 epochs of training
# Average env speed is 2769 ts/second
#
# Savinig models after 25800 epochs of training
# Average env speed is 2549 ts/second
# ---------------25800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 25900 epochs of training
# Average env speed is 2751 ts/second
#
# Savinig models after 26000 epochs of training
# Average env speed is 2571 ts/second
# ---------------26000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 26100 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 26200 epochs of training
# Average env speed is 2545 ts/second
# ---------------26200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 26300 epochs of training
# Average env speed is 2771 ts/second
#
# Savinig models after 26400 epochs of training
# Average env speed is 2547 ts/second
# ---------------26400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 26500 epochs of training
# Average env speed is 2760 ts/second
#
# Savinig models after 26600 epochs of training
# Average env speed is 2566 ts/second
# ---------------26600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test         2.0
# -----------------------------------
#
# Savinig models after 26700 epochs of training
# Average env speed is 2743 ts/second
#
# Savinig models after 26800 epochs of training
# Average env speed is 2572 ts/second
# ---------------26800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.971875
# -----------------------------------
#
# Savinig models after 26900 epochs of training
# Average env speed is 2745 ts/second
#
# Savinig models after 27000 epochs of training
# Average env speed is 2525 ts/second
# ---------------27000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.965625
# -----------------------------------
#
# Savinig models after 27100 epochs of training
# Average env speed is 2766 ts/second
#
# Savinig models after 27200 epochs of training
# Average env speed is 2551 ts/second
# ---------------27200---------------
# ...
# ---------------31200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.984375
# -----------------------------------
#
# Savinig models after 31300 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 31400 epochs of training
# Average env speed is 2568 ts/second
# ---------------31400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.996875
# -----------------------------------
#
# Savinig models after 31500 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 31600 epochs of training
# Average env speed is 2554 ts/second
# ---------------31600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 31700 epochs of training
# Average env speed is 2775 ts/second
#
# Savinig models after 31800 epochs of training
# Average env speed is 2549 ts/second
# ---------------31800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.940625
# -----------------------------------
#
# Savinig models after 31900 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 32000 epochs of training
# Average env speed is 2562 ts/second
# ---------------32000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.984375
# -----------------------------------
#
# Savinig models after 32100 epochs of training
# Average env speed is 2761 ts/second
#
# Savinig models after 32200 epochs of training
# Average env speed is 2578 ts/second
# ---------------32200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 32300 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 32400 epochs of training
# Average env speed is 2551 ts/second
# ---------------32400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 32500 epochs of training
# Average env speed is 2773 ts/second
#
# Savinig models after 32600 epochs of training
# Average env speed is 2549 ts/second
# ---------------32600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 32700 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 32800 epochs of training
# Average env speed is 2555 ts/second
# ---------------32800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
# Savinig models after 32900 epochs of training
# Average env speed is 2751 ts/second
#
# Savinig models after 33000 epochs of training
# Average env speed is 2574 ts/second
# ---------------33000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.975
# -----------------------------------
#
# Savinig models after 33100 epochs of training
# Average env speed is 2745 ts/second
#
# Savinig models after 33200 epochs of training
# Average env speed is 2549 ts/second
# ---------------33200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.990625
# -----------------------------------
#
# Savinig models after 33300 epochs of training
# Average env speed is 2773 ts/second
#
# Savinig models after 33400 epochs of training
# Average env speed is 2556 ts/second
# ---------------33400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 33500 epochs of training
# Average env speed is 2758 ts/second
#
# Savinig models after 33600 epochs of training
# Average env speed is 2564 ts/second
# ---------------33600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.975
# -----------------------------------
#
# Savinig models after 33700 epochs of training
# Average env speed is 2744 ts/second
#
# Savinig models after 33800 epochs of training
# Average env speed is 2560 ts/second
# ---------------33800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 33900 epochs of training
# Average env speed is 2747 ts/second
#
# Savinig models after 34000 epochs of training
# Average env speed is 2551 ts/second
# ---------------34000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 34100 epochs of training
# Average env speed is 2758 ts/second
#
# Savinig models after 34200 epochs of training
# Average env speed is 2547 ts/second
# ---------------34200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 34300 epochs of training
# Average env speed is 2765 ts/second
#
# Savinig models after 34400 epochs of training
# Average env speed is 2563 ts/second
# ---------------34400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 34500 epochs of training
# Average env speed is 2758 ts/second
#
# Savinig models after 34600 epochs of training
# Average env speed is 2551 ts/second
# ---------------34600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test        1.95
# -----------------------------------
#
# Savinig models after 34700 epochs of training
# Average env speed is 2767 ts/second
#
# Savinig models after 34800 epochs of training
# Average env speed is 2532 ts/second
# ---------------34800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.953125
# -----------------------------------
#
# Savinig models after 34900 epochs of training
# Average env speed is 2769 ts/second
#
# Savinig models after 35000 epochs of training
# Average env speed is 2547 ts/second
# ---------------35000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 35100 epochs of training
# Average env speed is 2742 ts/second
#
# Savinig models after 35200 epochs of training
# Average env speed is 2561 ts/second
# ---------------35200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.953125
# -----------------------------------
#
# Savinig models after 35300 epochs of training
# Average env speed is 2754 ts/second
#
# Savinig models after 35400 epochs of training
# Average env speed is 2553 ts/second
# ---------------35400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 35500 epochs of training
# Average env speed is 2773 ts/second
#
# Savinig models after 35600 epochs of training
# Average env speed is 2549 ts/second
# ---------------35600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.971875
# -----------------------------------
#
# Savinig models after 35700 epochs of training
# Average env speed is 2748 ts/second
#
# Savinig models after 35800 epochs of training
# Average env speed is 2547 ts/second
# ---------------35800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 35900 epochs of training
# Average env speed is 2755 ts/second
#
# Savinig models after 36000 epochs of training
# Average env speed is 2565 ts/second
# ---------------36000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.990625
# -----------------------------------
#
# Savinig models after 36100 epochs of training
# Average env speed is 2759 ts/second
#
# Savinig models after 36200 epochs of training
# Average env speed is 2548 ts/second
# ---------------36200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 36300 epochs of training
# Average env speed is 2762 ts/second
#
# Savinig models after 36400 epochs of training
# Average env speed is 2542 ts/second
# ---------------36400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.98125
# -----------------------------------
#
# Savinig models after 36500 epochs of training
# Average env speed is 2759 ts/second
#
# Savinig models after 36600 epochs of training
# Average env speed is 2566 ts/second
# ---------------36600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 36700 epochs of training
# Average env speed is 2737 ts/second
#
# Savinig models after 36800 epochs of training
# Average env speed is 2566 ts/second
# ---------------36800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.971875
# -----------------------------------
#
# Savinig models after 36900 epochs of training
# Average env speed is 2745 ts/second
#
# Savinig models after 37000 epochs of training
# Average env speed is 2552 ts/second
# ---------------37000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 37100 epochs of training
# Average env speed is 2773 ts/second
#
# Savinig models after 37200 epochs of training
# Average env speed is 2550 ts/second
# ---------------37200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.94375
# -----------------------------------
#
# Savinig models after 37300 epochs of training
# Average env speed is 2753 ts/second
#
# Savinig models after 37400 epochs of training
# Average env speed is 2567 ts/second
# ---------------37400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 37500 epochs of training
# Average env speed is 2748 ts/second
#
# Savinig models after 37600 epochs of training
# Average env speed is 2548 ts/second
# ---------------37600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test       1.975
# -----------------------------------
#
# Savinig models after 37700 epochs of training
# Average env speed is 2746 ts/second
#
# Savinig models after 37800 epochs of training
# Average env speed is 2542 ts/second
# ---------------37800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
# Savinig models after 37900 epochs of training
# Average env speed is 2769 ts/second
#
# Savinig models after 38000 epochs of training
# Average env speed is 2550 ts/second
# ---------------38000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.978125
# -----------------------------------
#
# Savinig models after 38100 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 38200 epochs of training
# Average env speed is 2568 ts/second
# ---------------38200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.990625
# -----------------------------------
#
# Savinig models after 38300 epochs of training
# Average env speed is 2750 ts/second
#
# Savinig models after 38400 epochs of training
# Average env speed is 2554 ts/second
# ---------------38400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.990625
# -----------------------------------
#
# Savinig models after 38500 epochs of training
# Average env speed is 2757 ts/second
#
# Savinig models after 38600 epochs of training
# Average env speed is 2540 ts/second
# ---------------38600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 38700 epochs of training
# Average env speed is 2760 ts/second
#
# Savinig models after 38800 epochs of training
# Average env speed is 2550 ts/second
# ---------------38800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 38900 epochs of training
# Average env speed is 2752 ts/second
#
# Savinig models after 39000 epochs of training
# Average env speed is 2561 ts/second
# ---------------39000---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.965625
# -----------------------------------
#
# Savinig models after 39100 epochs of training
# Average env speed is 2764 ts/second
#
# Savinig models after 39200 epochs of training
# Average env speed is 2361 ts/second
# ---------------39200---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test    1.921875
# -----------------------------------
#
# Savinig models after 39300 epochs of training
# Average env speed is 2572 ts/second
#
# Savinig models after 39400 epochs of training
# Average env speed is 2544 ts/second
# ---------------39400---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test        1.95
# -----------------------------------
#
# Savinig models after 39500 epochs of training
# Average env speed is 2733 ts/second
#
# Savinig models after 39600 epochs of training
# Average env speed is 2562 ts/second
# ---------------39600---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test      1.9875
# -----------------------------------
#
# Savinig models after 39700 epochs of training
# Average env speed is 2739 ts/second
#
# Savinig models after 39800 epochs of training
# Average env speed is 2545 ts/second
# ---------------39800---------------
# Matrix of models performance with each others:
#             agent_test
# agent_test     1.99375
# -----------------------------------
#
# Savinig models after 39900 epochs of training
# Average env speed is 2745 ts/second
# GAME PARAMETERS:
#   observation length = 171
#   number of actions = 11
#   number of players = 2
# <class 'PPO.ppo.Model'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-3eec1a07d7ce> in <module>
#      21 runname = 'FC_k:%d_steps:%d' %(k, nsteps)
#      22 learn_pool.run_experiment(runname, [mc], env_config, rewards_config, numepochs,
# ---> 23                           folder = folder, method = method, nsteps = nsteps,)
#      24 #LSTM copy
#      25
#
# ~/Documents/HLE github/hanabi/learning/learn_pool.py in run_experiment(run_name, models_configs, env_config, rewards_configs, nupdates, episodes, nsteps, change_lr, save_every, summary_every, evaluation_every, eval_eps, folder, method)
#     112     gamefn = GameLSTM if models_configs[0]['lstm_layers'] else Game
#     113     print(modelfn)
# --> 114     models = [modelfn(nactions, nobs, nplayers, sess = sess, **mc) for mc in models_configs]
#     115     # create game
#     116     if method == 'single agent':
#
# ~/Documents/HLE github/hanabi/learning/learn_pool.py in <listcomp>(.0)
#     112     gamefn = GameLSTM if models_configs[0]['lstm_layers'] else Game
#     113     print(modelfn)
# --> 114     models = [modelfn(nactions, nobs, nplayers, sess = sess, **mc) for mc in models_configs]
#     115     # create game
#     116     if method == 'single agent':
#
# TypeError: __init__() got an unexpected keyword argument 'lstm_layers'

# %%
k = 8
nsteps = 6
numepochs = 480000 // nsteps
folder = './experiments/baselines/architecture/'

#LSTM ent
mc = dict(model_config_base)
mc['k'] = k
mc['nsteps'] = nsteps
mc['lstm_layers'] = [128]
mc['v_net'] = 'copy'
mc['ent_coef'] = 0.01
runname = 'LSTM_copy_k:%d_steps:%d' %(k, nsteps)
learn_pool.run_experiment(runname, [mc], env_config, rewards_config, numepochs, 
                          folder = folder, method = method, nsteps = nsteps,)
